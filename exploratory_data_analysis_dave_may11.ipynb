# %%
import pandas as pd
import numpy as np

df = pd.read_csv('internet_services_and_tech.csv')

# %%
df.head()
# Out:
#    REF_DATE     GEO           DGUID Type of Internet service and technology  \
# 0      2018  Canada  2016A000011124     Have access to the Internet at home
# 1      2018  Canada  2016A000011124     Have access to the Internet at home
# 2      2018  Canada  2016A000011124     Have access to the Internet at home
# 3      2018  Canada  2016A000011124     Have access to the Internet at home
# 4      2018  Canada  2016A000011124     Have access to the Internet at home
#
#                                       Age group  \
# 0  Total, Internet users aged 15 years and over
# 1  Total, Internet users aged 15 years and over
# 2  Total, Internet users aged 15 years and over
# 3  Total, Internet users aged 15 years and over
# 4  Total, Internet users aged 15 years and over
#
#            Household income quartile      UOM  UOM_ID SCALAR_FACTOR  \
# 0  Total, household income quartiles  Percent     239         units
# 1   Lowest quartile household income  Percent     239         units
# ...

# %%
df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Type of Internet service and technology',
#        'Age group', 'Household income quartile', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
for col in df:
    print(col, "unique", df[col].unique())
    print("")
# Out:
# REF_DATE unique [2018]
#
# GEO unique ['Canada' 'Atlantic provinces' 'Quebec' 'Ontario' 'Prairie provinces'
#  'British Columbia']
#
# DGUID unique ['2016A000011124' '2016A00011' '2016A000224' '2016A000235' '2016A00014'
#  '2016A000259']
#
# Type of Internet service and technology unique ['Have access to the Internet at home'
#  'Use of a smart home devices in primary residence '
#  'Have a smartphone for personal use' 'Have social networking accounts'
#  'Used or purchased video streaming services'
#  'Used or purchased music streaming services'
#  'Used government services online ' 'Shopped online']
#
# Age group unique ['Total, Internet users aged 15 years and over'
#  'Internet users aged 15 to 24 years' 'Internet users aged 25 to 44 years'
#  'Internet users aged 45 to 64 years'
#  'Internet users aged 65 years and over']
#
# Household income quartile unique ['Total, household income quartiles' 'Lowest quartile household income'
# ...

# %%
df.loc[df['GEO'] == "Prairie provinces"].drop(columns = ['DGUID', 'UOM', 'UOM_ID', 'SCALAR_ID'])
# Out:
#      REF_DATE                GEO Type of Internet service and technology  \
# 800      2018  Prairie provinces     Have access to the Internet at home
# 801      2018  Prairie provinces     Have access to the Internet at home
# 802      2018  Prairie provinces     Have access to the Internet at home
# 803      2018  Prairie provinces     Have access to the Internet at home
# 804      2018  Prairie provinces     Have access to the Internet at home
# ..        ...                ...                                     ...
# 995      2018  Prairie provinces                          Shopped online
# 996      2018  Prairie provinces                          Shopped online
# 997      2018  Prairie provinces                          Shopped online
# 998      2018  Prairie provinces                          Shopped online
# 999      2018  Prairie provinces                          Shopped online
#
#                                         Age group  \
# ...
